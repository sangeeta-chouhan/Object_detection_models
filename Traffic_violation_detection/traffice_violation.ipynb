# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
model = YOLO("yolo26n.pt")  # load a pretrained model (recommended for training)
# Out:
# Ultralytics 8.4.26 🚀 Python-3.10.20 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Setup complete ✅ (16 CPUs, 7.5 GB RAM, 95.2/1006.9 GB disk)

# %%
# How to load later 

from ultralytics import YOLO

model = YOLO("best (1).pt")   # custom model

# Predict with the model
results = model("/mnt/d/Python/Machine_learning/Traffic_violation_detection_dataset/images/train/pkdarabi_test_FisheyeCamera_1_00194_png.rf.21c8dbe947c18776eaab4e5caec1585b.jpg")  # predict on an image
#results = model("/mnt/d/Python/Images/pexels-mwabonje-1806900.jpg")

# Access the results
for result in results:
    xywh = result.boxes.xywh  # center-x, center-y, width, height
    xywhn = result.boxes.xywhn  # normalized
    xyxy = result.boxes.xyxy  # top-left-x, top-left-y, bottom-right-x, bottom-right-y
    xyxyn = result.boxes.xyxyn  # normalized
    names = [result.names[cls.item()] for cls in result.boxes.cls.int()]  # class name of each box
    confs = result.boxes.conf  # confidence score of each box

    for i in range(len(names)):
        print(f"Object:{names[i]} , Confidence:{ confs[i]:.2f}, Box:{xyxy[i]} ")

# Show image with detections
result[0].show()

#Save result image
#results[0].save(filename="output.jpg")
# Out:
# image 1/1 /mnt/d/Python/Machine_learning/Traffic_violation_detection_dataset/images/train/pkdarabi_test_FisheyeCamera_1_00194_png.rf.21c8dbe947c18776eaab4e5caec1585b.jpg: 640x640 1 green light, 68.1ms
# Speed: 5.0ms preprocess, 68.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 640)
# Object:green light , Confidence:0.29, Box:tensor([145.5666, 199.7860, 149.2903, 202.8952], device='cuda:0')
# <PIL.Image.Image image mode=RGB size=416x416>
